    [-0.053467, -0.021240, -0.041992, -0.043701, -0.112305, 0.000011, -0.000005, -0.017334, -0.034180, -0.006744, 0.000008, -0.285156, -0.087891, -0.091309, -0.023926, -0.022095],
    [-0.055176, -0.009888, -0.002350, -0.052734, -0.021729, -0.000045, -0.063965, -0.066406, -0.000003, -0.076172, -0.000009, -0.013977, -0.096680, -0.035400, 0.005310, -0.043457],
    [-0.000010, -0.074707, -0.000029, 0.000005, -0.067383, -0.000002, -0.000000, -0.025879, -0.039307, -0.015381, -0.011963, -0.038574, -0.034668, -0.016235, 0.000011, 0.000018],
    [-0.023071, 0.000002, 0.000005, 0.000002, 0.005554, -0.002701, 0.000004, 0.006531, -0.000001, 0.000003, 0.000005, -0.002472, -0.000931, -0.008301, -0.010925, -0.000002],
    [-0.000002, -0.003235, -0.003845, -0.001694, -0.000003, -0.007172, -0.000006, 0.008667, 0.000004, -0.002029, -0.000002, -0.000010, -0.000005, -0.000002, 0.006012, -0.000001],
    [0.000021, -0.002625, -0.000007, -0.002213, -0.000008, 0.018066, 0.000016, 0.000014, -0.000005, 0.000010, -0.001022, -0.002258, -0.000002, -0.001907, -0.000018, -0.000144]
]

# 转换为numpy数组，转置使得头在Y轴，层在X轴
data_array = np.array(data).T  # shape: (16, 24)

print("数据已加载完成")
print(f"数据形状: {data_array.shape} (16个头 × 24层)")
print(f"数值范围: [{np.min(data_array):.6f}, {np.max(data_array):.6f}]")
# Out:
# 数据已加载完成
# 数据形状: (16, 24) (16个头 × 24层)
# 数值范围: [-0.902344, 0.018066]

# %%
# 设置全局字体为Times New Roman，统一字号
plt.rcParams['font.family'] = 'Times New Roman'
plt.rcParams['font.size'] = 16  # 统一基础字号

# 创建热力图
fig, ax = plt.subplots(figsize=(12, 8))

# 绘制热力图 - 注意这里的extent参数帮助正确放置图像
im = ax.imshow(data_array, cmap='RdBu_r', aspect='auto', interpolation='nearest',
               extent=[-0.5, 23.5, 15.5, -0.5])  # 设置extent以对齐网格

ax.set_xlabel('Layer', fontsize=14)
ax.set_ylabel('Attention Head', fontsize=14)
# ax.set_title('Softmax Offset Values Heatmap (After Softmax Bias)', fontsize=13, fontweight='bold')

# 设置主刻度（数字标签的位置）
ax.set_xticks(range(24))
ax.set_yticks(range(16))
ax.set_xticklabels(range(24), fontsize=12)
ax.set_yticklabels(range(16), fontsize=12)

# 设置次刻度用于网格线（在格子边缘）
ax.set_xticks(np.arange(-0.5, 24, 1), minor=True)
ax.set_yticks(np.arange(-0.5, 16, 1), minor=True)

# 画白色网格线作为边框
ax.grid(which='minor', color='white', linestyle='-', linewidth=1.5, alpha=1.0)
# 关闭主刻度的网格线
ax.grid(which='major', visible=False)

# 移除刻度线
ax.tick_params(which='both', length=0)

# 隐藏所有边框
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)

# 添加颜色条
cbar = plt.colorbar(im, ax=ax, pad=0.02)
cbar.set_label('Leakage Bias', fontsize=14)
cbar.ax.tick_params(labelsize=12)

# 获取colormap和normalization用于判断颜色
from matplotlib.colors import Normalize
norm = Normalize(vmin=data_array.min(), vmax=data_array.max())
cmap = plt.cm.RdBu_r

# 添加数值标注（优化颜色判断）
for i in range(16):
    for j in range(24):
        value = data_array[i, j]

        # 根据实际背景颜色来决定文字颜色
        # 获取该位置的颜色值
        bg_color = cmap(norm(value))
        # 计算背景颜色的亮度 (使用感知亮度公式)
        luminance = 0.299 * bg_color[0] + 0.587 * bg_color[1] + 0.114 * bg_color[2]
        # 如果背景较暗用白色，背景较亮用黑色
        text_color = 'white' if luminance < 0.5 else 'black'

        # 格式化为2位小数，包括0.00
        formatted_value = f'{value:.2f}'
        ax.text(j, i, formatted_value, ha='center', va='center',
                fontsize=9, color=text_color, fontfamily='Times New Roman')

plt.tight_layout()
# 保存到PDF文件
plt.savefig('./softmaxbiasheatmap.pdf',
            format='pdf',
            dpi=300,
            bbox_inches='tight',
            facecolor='white',
            edgecolor='none')
plt.close()  # 关闭图形以释放内存

print("图片已保存为 softmax_offset_heatmap.pdf")

# 恢复默认字体设置（可选）
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.size'] = 10
# Out:
# 图片已保存为 softmax_offset_heatmap.pdf

# %%
# 设置全局字体为Times New Roman，统一字号
plt.rcParams['font.family'] = 'Times New Roman'
plt.rcParams['font.size'] = 16  # 统一基础字号

# 计算每层的统计数据
layer_means = np.mean(data_array, axis=0)
layer_stds = np.std(data_array, axis=0)

# 创建条形图（高度改为3）
fig, ax = plt.subplots(figsize=(12, 4))

# 绘制条形图
bars = ax.bar(range(24), layer_means, yerr=layer_stds, capsize=3, alpha=0.7,
               color='#276CF5', edgecolor='black', linewidth=0.5)

# 根据值的正负给条形图着色
colors = ['crimson' if val > 0 else '#276CF5' for val in layer_means]
for bar, color in zip(bars, colors):
    bar.set_color(color)

ax.axhline(y=0, color='grey', linestyle='-', linewidth=1, alpha=0.3)
ax.set_xlabel('Layer', fontsize=18)
ax.set_ylabel('Head-Averaged Leakage Bias', fontsize=18)
# 不要标题
ax.set_xticks(range(24))
ax.set_xticklabels(range(24), fontsize=16)
ax.tick_params(axis='y', labelsize=16)
ax.grid(axis='y', alpha=0.3)

# 调整y轴范围，给下方留更多空间
y_min = min(layer_means - layer_stds) - 0.1  # 下方多留0.1的空间
y_max = max(layer_means + layer_stds) + 0.05  # 上方留一点空间
ax.set_ylim(y_min, y_max)


# 添加数值标注
for i, (mean, std) in enumerate(zip(layer_means, layer_stds)):
    if abs(mean) > 0.01:  # 只标注绝对值大于0.01的值
        ax.text(i, mean + std + 0.02 if mean > 0 else mean - std - 0.02,
                f'{mean:.2f}', ha='center', va='bottom' if mean > 0 else 'top',
                fontsize=12, rotation=0, fontfamily='Times New Roman')

plt.tight_layout()

# 保存到PDF文件
plt.savefig('./softmaxbiasbarplot.pdf',
            format='pdf',
            dpi=300,
            bbox_inches='tight',
            facecolor='white',
            edgecolor='none')
plt.close()

print("图片已保存为 softmax_offset_barplot.pdf")

# 恢复默认字体设置
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.size'] = 10

# 打印分析
print("\n" + "="*60)
print("层级分析")
print("="*60)
for i in range(24):
    print(f"Layer {i:2d}: mean={layer_means[i]:+.4f}, std={layer_stds[i]:.4f}, "
          f"range=[{data_array[:, i].min():.4f}, {data_array[:, i].max():.4f}]")
# Out:
# 图片已保存为 softmax_offset_barplot.pdf
#
# ...
# 层级分析
# ...
# Layer  0: mean=-0.8684, std=0.1033, range=[-0.9023, -0.4688]
# Layer  1: mean=-0.5414, std=0.2322, range=[-0.7500, -0.0238]
# Layer  2: mean=-0.5558, std=0.2361, range=[-0.7812, -0.0513]
# Layer  3: mean=-0.5524, std=0.1805, range=[-0.7188, -0.0352]
# Layer  4: mean=-0.5113, std=0.1945, range=[-0.7031, -0.0029]
# Layer  5: mean=-0.4577, std=0.1823, range=[-0.6328, -0.0275]
# Layer  6: mean=-0.4138, std=0.2202, range=[-0.6289, -0.0001]
# Layer  7: mean=-0.2796, std=0.1906, range=[-0.5898, -0.0050]
# Layer  8: mean=-0.2867, std=0.2210, range=[-0.5664, -0.0029]
# Layer  9: mean=-0.2721, std=0.1582, range=[-0.4941, -0.0004]
# Layer 10: mean=-0.1451, std=0.1659, range=[-0.4238, -0.0000]
# Layer 11: mean=-0.1298, std=0.1443, range=[-0.4355, -0.0005]
# Layer 12: mean=-0.0633, std=0.0981, range=[-0.3340, -0.0000]
# Layer 13: mean=-0.0487, std=0.0845, range=[-0.3027, -0.0000]
# Layer 14: mean=-0.0485, std=0.0644, range=[-0.1768, 0.0000]
# ...
